# %% [markdown]
# #Comparing Median Income by County in Texas from 2014-2015
#
# ## Overview: This notebook will outline the steps needed in order to assemble a dataset overviewing median incomes across counties in Texas from 2014-2015. The subdata compiled was culled from the 2014-2015 Public Health Data records.

# %% [markdown]
# Below is a step by step instruction manual on how to cull this data.

# %% [markdown]
# ### ***Getting Started***

# %% [markdown]
# **Starting with Pandas**
#
# Pandas is the package that will help you sort through the dataset.

# %% [markdown]
# Add code saying `import pandas as pd` and `import numpy as np` and run it

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Reading the File in**

# %% [markdown]
#  Import the csv file called "CountyHealthData_2014-2015.csv". To do this go to the files section on the left side of your notebook and select upload file, and proceed to upload said file.
#
#
# To read the file into the notebook insert the code: `df=pd.read_csv("CountyHealthData_2014-2015.csv")`. The file was given to us by Professor Gotzler and is linked in the file section of this notebook.
#
# **Important:**
#
# Before running the code below ensure that the csv is in your file folder

# %%
df=pd.read_csv("CountyHealthData_2014-2015.csv")

# %% [markdown]
# ### ***Understanding the Size of the Original Dataset***

# %% [markdown]
# Use `df.shape`, and `df.size` to get the data about the size of the file. The size will be the number of blocks and the shape will have number of (rows,columns)

# %%
df.shape
# Out:
# (6109, 64)

# %%
df.size
# Out:
# 390976

# %% [markdown]
# Use `df.columns` to get an overview of all the columns of information in the file

# %%
df.columns
# Out:
# Index(['State', 'Region', 'Division', 'County', 'FIPS', 'GEOID', 'SMS Region',
#        'Year', 'Premature death', 'Poor or fair health',
#        'Poor physical health days', 'Poor mental health days',
#        'Low birthweight', 'Adult smoking', 'Adult obesity',
#        'Food environment index', 'Physical inactivity',
#        'Access to exercise opportunities', 'Excessive drinking',
#        'Alcohol-impaired driving deaths', 'Sexually transmitted infections',
#        'Teen births', 'Uninsured', 'Primary care physicians', 'Dentists',
#        'Mental health providers', 'Preventable hospital stays',
#        'Diabetic screening', 'Mammography screening', 'High school graduation',
#        'Some college', 'Unemployment', 'Children in poverty',
#        'Income inequality', 'Children in single-parent households',
#        'Social associations', 'Violent crime', 'Injury deaths',
#        'Air pollution - particulate matter', 'Drinking water violations',
#        'Severe housing problems', 'Driving alone to work',
#        'Long commute - driving alone', '2011 population estimate',
#        'Population that is not proficient in English',
#        'Population living in a rural area', 'Diabetes', 'HIV prevalence rate',
#        'Premature age-adjusted mortality', 'Infant mortality',
#        'Child mortality', 'Food insecurity', 'Limited access to healthy foods',
#        'Motor vehicle crash deaths', 'Drug poisoning deaths',
#        'Uninsured adults', 'Uninsured children', 'Health care costs',
#        'Could not see doctor due to cost', 'Other primary care providers',
#        'Median household income', 'Children eligible for free lunch',
#        'Homicide rate', 'Inadequate social support'],
#       dtype='object')

# %% [markdown]
# ### ***Creating the Texas Subset***

# %% [markdown]
# Once you have decided your chosen topic, use code `df[df["State"] == "TX"]` to narrow it down to your chosen information, in which I chose Texas to look at.

# %%
df[df["State"] == "TX"]
# Out:
#      State Region            Division           County   FIPS  GEOID  \
# 4914    TX  South  West South Central  Anderson County  48001  48001
# 4915    TX  South  West South Central  Anderson County  48001  48001
# 4916    TX  South  West South Central   Andrews County  48003  48003
# 4917    TX  South  West South Central   Andrews County  48003  48003
# 4918    TX  South  West South Central  Angelina County  48005  48005
# ...    ...    ...                 ...              ...    ...    ...
# 5378    TX  South  West South Central     Young County  48503  48503
# 5379    TX  South  West South Central    Zapata County  48505  48505
# 5380    TX  South  West South Central    Zapata County  48505  48505
# 5381    TX  South  West South Central    Zavala County  48507  48507
# 5382    TX  South  West South Central    Zavala County  48507  48507
#
#      SMS Region      Year  Premature death  Poor or fair health  ...  \
# 4914  Region 10  1/1/2014          10526.0                0.213  ...
# 4915  Region 10  1/1/2015          10106.0                0.213  ...
# 4916  Region 10  1/1/2014           7970.0                0.282  ...
# 4917  Region 10  1/1/2015           8960.0                0.282  ...
# 4918  Region 10  1/1/2014           8965.0                0.259  ...
# ...         ...       ...              ...                  ...  ...
# 5378  Region 10  1/1/2015           9829.0                0.251  ...
# 5379  Region 10  1/1/2014           7267.0                0.275  ...
# 5380  Region 10  1/1/2015           6366.0                0.275  ...
# 5381  Region 10  1/1/2014           7854.0                  NaN  ...
# 5382  Region 10  1/1/2015           8345.0                  NaN  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 4914                  15.62             0.317               0.146
# 4915                  14.02             0.300               0.145
# 4916                    NaN             0.315               0.188
# 4917                    NaN             0.290               0.162
# 4918                   7.11             0.309               0.134
# ...                     ...               ...                 ...
# 5378                  24.16             0.311               0.169
# 5379                    NaN             0.466               0.172
# 5380                    NaN             0.431               0.155
# 5381                    NaN             0.376               0.130
# 5382                  13.41             0.361               0.121
#
#       Health care costs  Could not see doctor due to cost  \
# 4914            10329.0                             0.178
# 4915            10784.0                             0.178
# 4916             9089.0                               NaN
# 4917             9262.0                               NaN
# 4918            11316.0                             0.250
# ...                 ...                               ...
# 5378            12149.0                               NaN
# 5379            12973.0                               NaN
# 5380            11651.0                               NaN
# 5381            10271.0                               NaN
# 5382            11417.0                               NaN
#
#       Other primary care providers  Median household income  \
# 4914                          24.0                    41530
# 4915                          28.0                    41279
# 4916                          37.0                    57690
# 4917                          54.0                    62781
# 4918                          40.0                    39747
# ...                            ...                      ...
# 5378                          33.0                    44372
# 5379                          14.0                    33462
# 5380                          21.0                    34506
# 5381                          50.0                    25157
# 5382                          41.0                    25291
#
#       Children eligible for free lunch  Homicide rate  \
# 4914                             0.521           6.70
# 4915                             0.534           7.00
# 4916                             0.200            NaN
# 4917                             0.173            NaN
# 4918                             0.588           5.76
# ...                                ...            ...
# 5378                             0.457            NaN
# 5379                             0.707            NaN
# 5380                             0.671            NaN
# 5381                             0.732            NaN
# 5382                             0.745            NaN
#
#       Inadequate social support
# 4914                      0.303
# 4915                        NaN
# 4916                        NaN
# 4917                        NaN
# 4918                      0.257
# ...                         ...
# 5378                        NaN
# 5379                        NaN
# 5380                        NaN
# 5381                        NaN
# 5382                        NaN
#
# [469 rows x 64 columns]

# %% [markdown]
# Make a subset of data for Texas from the larger data pool calling it TX_subset, making it easier to access. Type in code `TX_subset=df[df["State"] == "TX"].copy()` to create the subset. Then on the next line type `TX_subset` to see the data below

# %%
TX_subset=df[df["State"] == "TX"].copy()


TX_subset
# Out:
#      State Region            Division           County   FIPS  GEOID  \
# 4914    TX  South  West South Central  Anderson County  48001  48001
# 4915    TX  South  West South Central  Anderson County  48001  48001
# 4916    TX  South  West South Central   Andrews County  48003  48003
# 4917    TX  South  West South Central   Andrews County  48003  48003
# 4918    TX  South  West South Central  Angelina County  48005  48005
# ...    ...    ...                 ...              ...    ...    ...
# 5378    TX  South  West South Central     Young County  48503  48503
# 5379    TX  South  West South Central    Zapata County  48505  48505
# 5380    TX  South  West South Central    Zapata County  48505  48505
# 5381    TX  South  West South Central    Zavala County  48507  48507
# 5382    TX  South  West South Central    Zavala County  48507  48507
#
#      SMS Region      Year  Premature death  Poor or fair health  ...  \
# 4914  Region 10  1/1/2014          10526.0                0.213  ...
# 4915  Region 10  1/1/2015          10106.0                0.213  ...
# 4916  Region 10  1/1/2014           7970.0                0.282  ...
# 4917  Region 10  1/1/2015           8960.0                0.282  ...
# 4918  Region 10  1/1/2014           8965.0                0.259  ...
# ...         ...       ...              ...                  ...  ...
# 5378  Region 10  1/1/2015           9829.0                0.251  ...
# 5379  Region 10  1/1/2014           7267.0                0.275  ...
# 5380  Region 10  1/1/2015           6366.0                0.275  ...
# 5381  Region 10  1/1/2014           7854.0                  NaN  ...
# 5382  Region 10  1/1/2015           8345.0                  NaN  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 4914                  15.62             0.317               0.146
# 4915                  14.02             0.300               0.145
# 4916                    NaN             0.315               0.188
# 4917                    NaN             0.290               0.162
# 4918                   7.11             0.309               0.134
# ...                     ...               ...                 ...
# 5378                  24.16             0.311               0.169
# 5379                    NaN             0.466               0.172
# 5380                    NaN             0.431               0.155
# 5381                    NaN             0.376               0.130
# 5382                  13.41             0.361               0.121
#
#       Health care costs  Could not see doctor due to cost  \
# 4914            10329.0                             0.178
# 4915            10784.0                             0.178
# 4916             9089.0                               NaN
# 4917             9262.0                               NaN
# 4918            11316.0                             0.250
# ...                 ...                               ...
# 5378            12149.0                               NaN
# 5379            12973.0                               NaN
# 5380            11651.0                               NaN
# 5381            10271.0                               NaN
# 5382            11417.0                               NaN
#
#       Other primary care providers  Median household income  \
# 4914                          24.0                    41530
# 4915                          28.0                    41279
# 4916                          37.0                    57690
# 4917                          54.0                    62781
# 4918                          40.0                    39747
# ...                            ...                      ...
# 5378                          33.0                    44372
# 5379                          14.0                    33462
# 5380                          21.0                    34506
# 5381                          50.0                    25157
# 5382                          41.0                    25291
#
#       Children eligible for free lunch  Homicide rate  \
# 4914                             0.521           6.70
# 4915                             0.534           7.00
# 4916                             0.200            NaN
# 4917                             0.173            NaN
# 4918                             0.588           5.76
# ...                                ...            ...
# 5378                             0.457            NaN
# 5379                             0.707            NaN
# 5380                             0.671            NaN
# 5381                             0.732            NaN
# 5382                             0.745            NaN
#
#       Inadequate social support
# 4914                      0.303
# 4915                        NaN
# 4916                        NaN
# 4917                        NaN
# 4918                      0.257
# ...                         ...
# 5378                        NaN
# 5379                        NaN
# 5380                        NaN
# 5381                        NaN
# 5382                        NaN
#
# [469 rows x 64 columns]

# %% [markdown]
# **Still, this subset is too big and needs to be narrowed down to what we actually want to focus on, median incomes**

# %% [markdown]
# Within your `TX_subset` of the data you can sort through it by columns located above when we used `df.columns`. I searched by the columns called "Median household income", "County", and "Year" to narrow my data to the specifc set I want

# %% [markdown]
# There are different ways you can see the data. You can look at the head or the tail of the data adding `.head()` or `.tail()` to the end of the line of code

# %%
TX_subset.loc[:,["Median household income","County","Year"]].head()
# Out:
#       Median household income           County      Year
# 4914                    41530  Anderson County  1/1/2014
# 4915                    41279  Anderson County  1/1/2015
# 4916                    57690   Andrews County  1/1/2014
# 4917                    62781   Andrews County  1/1/2015
# 4918                    39747  Angelina County  1/1/2014

# %%
TX_subset.loc[:,["Median household income","County","Year"]].tail()
# Out:
#       Median household income         County      Year
# 5378                    44372   Young County  1/1/2015
# 5379                    33462  Zapata County  1/1/2014
# 5380                    34506  Zapata County  1/1/2015
# 5381                    25157  Zavala County  1/1/2014
# 5382                    25291  Zavala County  1/1/2015

# %% [markdown]
# Although these both show important information, we need more randomness and a larger sample to see wider trends

# %% [markdown]
# Another way to look at the data is by random sample. Instead of using `.head()` or `.tail()` you can use `.sample(n=x)` with the x being the size you want the random sample to be

# %%
TX_subset.loc[:,["Median household income","County","Year"]].sample(n=50)
# Out:
#       Median household income              County      Year
# 5251                    49792       Panola County  1/1/2015
# 4990                    38866         Coke County  1/1/2015
# 4959                    43561     Burleson County  1/1/2014
# 5199                    33330       Marion County  1/1/2014
# 5359                    43791      Wichita County  1/1/2014
# 5342                    43220    Van Zandt County  1/1/2015
# 4970                    33905      Cameron County  1/1/2015
# 5368                    60844       Wilson County  1/1/2015
# 5117                    37610         Hill County  1/1/2014
# 5159                    40919         Kerr County  1/1/2014
# 4932                    50334      Bandera County  1/1/2015
# 5369                    48727      Winkler County  1/1/2014
# 5203                    42128        Mason County  1/1/2014
# 5220                    40120        Milam County  1/1/2015
# 5226                    41516     Montague County  1/1/2015
# 5110                    59260         Hays County  1/1/2015
# 5068                    49661       Gaines County  1/1/2015
# 5275                    37053       Reeves County  1/1/2015
# 5286                    35805       Sabine County  1/1/2014
# 5307                    52988    Somervell County  1/1/2014
# 5153                    37292       Karnes County  1/1/2014
# 5375                    55063       Yoakum County  1/1/2014
# 5000                    70322        Comal County  1/1/2015
# 5294                    37107     San Saba County  1/1/2014
# 5291                    42320  San Jacinto County  1/1/2015
# 5116                    34607      Hidalgo County  1/1/2015
# 5346                    40092       Walker County  1/1/2015
# 5361                    37304    Wilbarger County  1/1/2014
# 5139                    39219       Jasper County  1/1/2014
# 5276                    40970      Refugio County  1/1/2014
# 4965                    44736      Calhoun County  1/1/2014
# 5174                    36717         Lamb County  1/1/2015
# 5195                    34852         Lynn County  1/1/2014
# 5072                    47134        Garza County  1/1/2015
# 5282                    35593      Runnels County  1/1/2014
# 5171                    37943        Lamar County  1/1/2014
# 4991                    32231      Coleman County  1/1/2014
# 4921                    41666      Aransas County  1/1/2015
# 5065                    32276         Frio County  1/1/2014
# 5257                    43766        Pecos County  1/1/2015
# 5030                    33342       Dimmit County  1/1/2014
# 5382                    25291       Zavala County  1/1/2015
# 5051                    42392       Fannin County  1/1/2015
# 4944                    54914       Blanco County  1/1/2015
# 5259                    39833         Polk County  1/1/2015
# 5208                    32073     Maverick County  1/1/2015
# 4949                    64883     Brazoria County  1/1/2014
# 5164                    41271       Kinney County  1/1/2015
# 5181                    42201         Leon County  1/1/2014
# 5168                    34419         Knox County  1/1/2015

# %% [markdown]
# Within the TX_subset we created earlier, make a smaller data subset with the specific Median household income data by county, which will be your final data.

# %% [markdown]
# Create a name for this final data, in which I chose "Medianincometx". To make "Medianincometx" an actual subset you need to use the code
# `Medianincometx= TX_subset.loc[:,["Median household income","County","Year"]].sample(n=50)`

# %% [markdown]
# Then on a new line of code type `Medianincometx` which is your finished sorted data and that will present the data you have just sorted

# %%
Medianincometx= TX_subset.loc[:,["Median household income","County","Year"]].sample(n=50)

Medianincometx
# Out:
#       Median household income             County      Year
# 4963                    42963    Caldwell County  1/1/2014
# 5194                    46223     Lubbock County  1/1/2015
# 5192                    45669       Llano County  1/1/2015
# 5295                    36030    San Saba County  1/1/2015
# 5257                    43766       Pecos County  1/1/2015
# 5084                    46501       Gregg County  1/1/2015
# 5160                    42456        Kerr County  1/1/2015
# 5262                    32861    Presidio County  1/1/2014
# 5315                    37076     Swisher County  1/1/2014
# 4947                    40574       Bowie County  1/1/2014
# 5016                    42378      Dallam County  1/1/2015
# 5164                    41271      Kinney County  1/1/2015
# 5009                    55599       Crane County  1/1/2014
# 5325                    43393   Tom Green County  1/1/2014
# 5337                    32920      Uvalde County  1/1/2014
# 5069                    59588   Galveston County  1/1/2014
# 4980                    74915    Chambers County  1/1/2015
# 5210                    38408   McCulloch County  1/1/2015
# 5183                    48441     Liberty County  1/1/2014
# 5327                    57293      Travis County  1/1/2014
# 5028                    75099      Denton County  1/1/2015
# 5001                    36522    Comanche County  1/1/2014
# 4988                    37242     Cochran County  1/1/2015
# 4954                    39106    Brewster County  1/1/2015
# 4978                    40689      Castro County  1/1/2015
# 5208                    32073    Maverick County  1/1/2015
# 5188                    56484    Lipscomb County  1/1/2015
# 5145                    34546    Jim Hogg County  1/1/2014
# 4983                    34731   Childress County  1/1/2014
# 4926                    46631    Atascosa County  1/1/2015
# 4919                    41804    Angelina County  1/1/2015
# 5104                    43777    Harrison County  1/1/2015
# 4992                    33014     Coleman County  1/1/2015
# 5264                    41349       Rains County  1/1/2014
# 5000                    70322       Comal County  1/1/2015
# 5012                    50243    Crockett County  1/1/2015
# 5025                    37515       Delta County  1/1/2014
# 5010                    58901       Crane County  1/1/2015
# 4961                    49685      Burnet County  1/1/2014
# 5101                    51298      Harris County  1/1/2014
# 5062                    41497    Franklin County  1/1/2015
# 5187                    51003    Lipscomb County  1/1/2014
# 4942                    49655       Bexar County  1/1/2015
# 5023                    39481  Deaf Smith County  1/1/2014
# 5377                    43248       Young County  1/1/2014
# 5052                    46907     Fayette County  1/1/2014
# 5103                    44958    Harrison County  1/1/2014
# 5047                    40346       Erath County  1/1/2015
# 5281                    92466    Rockwall County  1/1/2015
# 5155                    55044     Kaufman County  1/1/2014
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# Medianincometx['Median household income'].plot(kind='hist', bins=20, title='Median household income')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# Medianincometx.groupby('Year').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Median household income']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = Medianincometx.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Year')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Year', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Median household income')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Year']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Year'}, axis=1)
#               .sort_values('Year', ascending=True))
#   xs = counted['Year']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = Medianincometx.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Year')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Year', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# Medianincometx['Median household income'].plot(kind='line', figsize=(8, 4), title='Median household income')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(Medianincometx['Year'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(Medianincometx, x='Median household income', y='Year', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ### ***Exporting the Data***

# %% [markdown]
# Finally to export your final data use the line of code `Medianincometx.to_csv('Medianincometx.csv')`

# %%
Medianincometx.to_csv('Medianincometx.csv')

# %% [markdown]
# With that code enetered, you should have a new file called Medianincometx in your files within your notebook

# %% [markdown]
# Once you see this file in your notebook, you can download it to your computer for whatever use you may have for it.
