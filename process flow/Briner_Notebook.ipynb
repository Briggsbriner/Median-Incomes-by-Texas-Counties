# %% [markdown]
# #How to Sort Through Large Amounts of Data
#
#
# ##Procedure
#
#   Open Colabs Notebook and import file you intend to sort through and collect data from. Then add code saying `import pandas as pd` and `import numpy as np`

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# To read the file into the notebook insert the code: `df=pd.read_csv("CountyHealthData_2014-2015.csv")`

# %%
df=pd.read_csv("CountyHealthData_2014-2015.csv")

# %% [markdown]
# Use `df.shape`, and `df.size` to get the data about the size of the file. The size will be the number of blocks and the shape will have number of (rows,columns)

# %%
df.shape
# Out:
# (6109, 64)

# %%
df.size
# Out:
# 390976

# %% [markdown]
# Use `df.columns` to get an overview of all the columns of information in the file

# %%
df.columns
# Out:
# Index(['State', 'Region', 'Division', 'County', 'FIPS', 'GEOID', 'SMS Region',
#        'Year', 'Premature death', 'Poor or fair health',
#        'Poor physical health days', 'Poor mental health days',
#        'Low birthweight', 'Adult smoking', 'Adult obesity',
#        'Food environment index', 'Physical inactivity',
#        'Access to exercise opportunities', 'Excessive drinking',
#        'Alcohol-impaired driving deaths', 'Sexually transmitted infections',
#        'Teen births', 'Uninsured', 'Primary care physicians', 'Dentists',
#        'Mental health providers', 'Preventable hospital stays',
#        'Diabetic screening', 'Mammography screening', 'High school graduation',
#        'Some college', 'Unemployment', 'Children in poverty',
#        'Income inequality', 'Children in single-parent households',
#        'Social associations', 'Violent crime', 'Injury deaths',
#        'Air pollution - particulate matter', 'Drinking water violations',
#        'Severe housing problems', 'Driving alone to work',
#        'Long commute - driving alone', '2011 population estimate',
#        'Population that is not proficient in English',
#        'Population living in a rural area', 'Diabetes', 'HIV prevalence rate',
#        'Premature age-adjusted mortality', 'Infant mortality',
#        'Child mortality', 'Food insecurity', 'Limited access to healthy foods',
#        'Motor vehicle crash deaths', 'Drug poisoning deaths',
#        'Uninsured adults', 'Uninsured children', 'Health care costs',
#        'Could not see doctor due to cost', 'Other primary care providers',
#        'Median household income', 'Children eligible for free lunch',
#        'Homicide rate', 'Inadequate social support'],
#       dtype='object')

# %% [markdown]
# Once you have decided your chosen topic, use code `df[df["State"] == "TX"]` to narrow it down to your chosen information, in which I chose Texas to look at.

# %%
df[df["State"] == "TX"]
# Out:
#      State Region            Division           County   FIPS  GEOID  \
# 4914    TX  South  West South Central  Anderson County  48001  48001
# 4915    TX  South  West South Central  Anderson County  48001  48001
# 4916    TX  South  West South Central   Andrews County  48003  48003
# 4917    TX  South  West South Central   Andrews County  48003  48003
# 4918    TX  South  West South Central  Angelina County  48005  48005
# ...    ...    ...                 ...              ...    ...    ...
# 5378    TX  South  West South Central     Young County  48503  48503
# 5379    TX  South  West South Central    Zapata County  48505  48505
# 5380    TX  South  West South Central    Zapata County  48505  48505
# 5381    TX  South  West South Central    Zavala County  48507  48507
# 5382    TX  South  West South Central    Zavala County  48507  48507
#
#      SMS Region      Year  Premature death  Poor or fair health  ...  \
# 4914  Region 10  1/1/2014          10526.0                0.213  ...
# 4915  Region 10  1/1/2015          10106.0                0.213  ...
# 4916  Region 10  1/1/2014           7970.0                0.282  ...
# 4917  Region 10  1/1/2015           8960.0                0.282  ...
# 4918  Region 10  1/1/2014           8965.0                0.259  ...
# ...         ...       ...              ...                  ...  ...
# 5378  Region 10  1/1/2015           9829.0                0.251  ...
# 5379  Region 10  1/1/2014           7267.0                0.275  ...
# 5380  Region 10  1/1/2015           6366.0                0.275  ...
# 5381  Region 10  1/1/2014           7854.0                  NaN  ...
# 5382  Region 10  1/1/2015           8345.0                  NaN  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 4914                  15.62             0.317               0.146
# 4915                  14.02             0.300               0.145
# 4916                    NaN             0.315               0.188
# 4917                    NaN             0.290               0.162
# 4918                   7.11             0.309               0.134
# ...                     ...               ...                 ...
# 5378                  24.16             0.311               0.169
# 5379                    NaN             0.466               0.172
# 5380                    NaN             0.431               0.155
# 5381                    NaN             0.376               0.130
# 5382                  13.41             0.361               0.121
#
#       Health care costs  Could not see doctor due to cost  \
# 4914            10329.0                             0.178
# 4915            10784.0                             0.178
# 4916             9089.0                               NaN
# 4917             9262.0                               NaN
# 4918            11316.0                             0.250
# ...                 ...                               ...
# 5378            12149.0                               NaN
# 5379            12973.0                               NaN
# 5380            11651.0                               NaN
# 5381            10271.0                               NaN
# 5382            11417.0                               NaN
#
#       Other primary care providers  Median household income  \
# 4914                          24.0                    41530
# 4915                          28.0                    41279
# 4916                          37.0                    57690
# 4917                          54.0                    62781
# 4918                          40.0                    39747
# ...                            ...                      ...
# 5378                          33.0                    44372
# 5379                          14.0                    33462
# 5380                          21.0                    34506
# 5381                          50.0                    25157
# 5382                          41.0                    25291
#
#       Children eligible for free lunch  Homicide rate  \
# 4914                             0.521           6.70
# 4915                             0.534           7.00
# 4916                             0.200            NaN
# 4917                             0.173            NaN
# 4918                             0.588           5.76
# ...                                ...            ...
# 5378                             0.457            NaN
# 5379                             0.707            NaN
# 5380                             0.671            NaN
# 5381                             0.732            NaN
# 5382                             0.745            NaN
#
#       Inadequate social support
# 4914                      0.303
# 4915                        NaN
# 4916                        NaN
# 4917                        NaN
# 4918                      0.257
# ...                         ...
# 5378                        NaN
# 5379                        NaN
# 5380                        NaN
# 5381                        NaN
# 5382                        NaN
#
# [469 rows x 64 columns]

# %% [markdown]
# Make a subset of data for Texas from the larger data pool calling it TX_subset, making it easier to access. Type in code `TX_subset=df[df["State"] == "TX"].copy()` to create the subset and then on the next line type `TX_subset` to see the data below

# %%
TX_subset=df[df["State"] == "TX"].copy()


TX_subset
# Out:
#      State Region            Division           County   FIPS  GEOID  \
# 4914    TX  South  West South Central  Anderson County  48001  48001
# 4915    TX  South  West South Central  Anderson County  48001  48001
# 4916    TX  South  West South Central   Andrews County  48003  48003
# 4917    TX  South  West South Central   Andrews County  48003  48003
# 4918    TX  South  West South Central  Angelina County  48005  48005
# ...    ...    ...                 ...              ...    ...    ...
# 5378    TX  South  West South Central     Young County  48503  48503
# 5379    TX  South  West South Central    Zapata County  48505  48505
# 5380    TX  South  West South Central    Zapata County  48505  48505
# 5381    TX  South  West South Central    Zavala County  48507  48507
# 5382    TX  South  West South Central    Zavala County  48507  48507
#
#      SMS Region      Year  Premature death  Poor or fair health  ...  \
# 4914  Region 10  1/1/2014          10526.0                0.213  ...
# 4915  Region 10  1/1/2015          10106.0                0.213  ...
# 4916  Region 10  1/1/2014           7970.0                0.282  ...
# 4917  Region 10  1/1/2015           8960.0                0.282  ...
# 4918  Region 10  1/1/2014           8965.0                0.259  ...
# ...         ...       ...              ...                  ...  ...
# 5378  Region 10  1/1/2015           9829.0                0.251  ...
# 5379  Region 10  1/1/2014           7267.0                0.275  ...
# 5380  Region 10  1/1/2015           6366.0                0.275  ...
# 5381  Region 10  1/1/2014           7854.0                  NaN  ...
# 5382  Region 10  1/1/2015           8345.0                  NaN  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 4914                  15.62             0.317               0.146
# 4915                  14.02             0.300               0.145
# 4916                    NaN             0.315               0.188
# 4917                    NaN             0.290               0.162
# 4918                   7.11             0.309               0.134
# ...                     ...               ...                 ...
# 5378                  24.16             0.311               0.169
# 5379                    NaN             0.466               0.172
# 5380                    NaN             0.431               0.155
# 5381                    NaN             0.376               0.130
# 5382                  13.41             0.361               0.121
#
#       Health care costs  Could not see doctor due to cost  \
# 4914            10329.0                             0.178
# 4915            10784.0                             0.178
# 4916             9089.0                               NaN
# 4917             9262.0                               NaN
# 4918            11316.0                             0.250
# ...                 ...                               ...
# 5378            12149.0                               NaN
# 5379            12973.0                               NaN
# 5380            11651.0                               NaN
# 5381            10271.0                               NaN
# 5382            11417.0                               NaN
#
#       Other primary care providers  Median household income  \
# 4914                          24.0                    41530
# 4915                          28.0                    41279
# 4916                          37.0                    57690
# 4917                          54.0                    62781
# 4918                          40.0                    39747
# ...                            ...                      ...
# 5378                          33.0                    44372
# 5379                          14.0                    33462
# 5380                          21.0                    34506
# 5381                          50.0                    25157
# 5382                          41.0                    25291
#
#       Children eligible for free lunch  Homicide rate  \
# 4914                             0.521           6.70
# 4915                             0.534           7.00
# 4916                             0.200            NaN
# 4917                             0.173            NaN
# 4918                             0.588           5.76
# ...                                ...            ...
# 5378                             0.457            NaN
# 5379                             0.707            NaN
# 5380                             0.671            NaN
# 5381                             0.732            NaN
# 5382                             0.745            NaN
#
#       Inadequate social support
# 4914                      0.303
# 4915                        NaN
# 4916                        NaN
# 4917                        NaN
# 4918                      0.257
# ...                         ...
# 5378                        NaN
# 5379                        NaN
# 5380                        NaN
# 5381                        NaN
# 5382                        NaN
#
# [469 rows x 64 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# TX_subset['FIPS'].plot(kind='hist', bins=20, title='FIPS')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# TX_subset['GEOID'].plot(kind='hist', bins=20, title='GEOID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# TX_subset['Premature death'].plot(kind='hist', bins=20, title='Premature death')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# TX_subset['Poor or fair health'].plot(kind='hist', bins=20, title='Poor or fair health')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# TX_subset.groupby('SMS Region').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# TX_subset.groupby('Year').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# TX_subset.plot(kind='scatter', x='FIPS', y='GEOID', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# TX_subset.plot(kind='scatter', x='GEOID', y='Premature death', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# TX_subset.plot(kind='scatter', x='Premature death', y='Poor or fair health', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# TX_subset.plot(kind='scatter', x='Poor or fair health', y='Poor physical health days', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['FIPS']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = TX_subset.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('SMS Region')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='SMS Region', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('FIPS')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['FIPS']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = TX_subset.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Year')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Year', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('FIPS')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['GEOID']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = TX_subset.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('SMS Region')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='SMS Region', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('GEOID')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['GEOID']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = TX_subset.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Year')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Year', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('GEOID')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# TX_subset['FIPS'].plot(kind='line', figsize=(8, 4), title='FIPS')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# TX_subset['GEOID'].plot(kind='line', figsize=(8, 4), title='GEOID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# TX_subset['Premature death'].plot(kind='line', figsize=(8, 4), title='Premature death')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# TX_subset['Poor or fair health'].plot(kind='line', figsize=(8, 4), title='Poor or fair health')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Year'].value_counts()
#     for x_label, grp in TX_subset.groupby('SMS Region')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('SMS Region')
# _ = plt.ylabel('Year')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(TX_subset['SMS Region'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(TX_subset, x='FIPS', y='SMS Region', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(TX_subset['Year'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(TX_subset, x='FIPS', y='Year', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(TX_subset['SMS Region'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(TX_subset, x='GEOID', y='SMS Region', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(TX_subset['Year'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(TX_subset, x='GEOID', y='Year', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# Within your `TX_subset` of the data you can sort through it by columns located above when we used `df.columns`. I searched by the columns called "Median household income", "County", and "Year" to narrow my data to the specifc set I want

# %% [markdown]
# There are different ways you can see the data. You can look at the head or the tail of the data adding `.head()` or `.tail()` to the end of the line of code

# %%
TX_subset.loc[:,["Median household income","County","Year"]].head()
# Out:
#       Median household income           County      Year
# 4914                    41530  Anderson County  1/1/2014
# 4915                    41279  Anderson County  1/1/2015
# 4916                    57690   Andrews County  1/1/2014
# 4917                    62781   Andrews County  1/1/2015
# 4918                    39747  Angelina County  1/1/2014

# %%
TX_subset.loc[:,["Median household income","County","Year"]].tail()
# Out:
#       Median household income         County      Year
# 5378                    44372   Young County  1/1/2015
# 5379                    33462  Zapata County  1/1/2014
# 5380                    34506  Zapata County  1/1/2015
# 5381                    25157  Zavala County  1/1/2014
# 5382                    25291  Zavala County  1/1/2015

# %% [markdown]
# Another way to look at the data is by random sample. Instead of using `.head()` or `.tail()` you can use `.sample(n=x)` with the x being the size you want the random sample to be

# %%
TX_subset.loc[:,["Median household income","County","Year"]].sample(n=50)
# Out:
#       Median household income             County      Year
# 5199                    33330      Marion County  1/1/2014
# 4933                    50024     Bastrop County  1/1/2014
# 5220                    40120       Milam County  1/1/2015
# 5214                    53714      Medina County  1/1/2015
# 5223                    37395    Mitchell County  1/1/2014
# 5002                    35434    Comanche County  1/1/2015
# 5270                    33598        Real County  1/1/2014
# 5280                    85164    Rockwall County  1/1/2014
# 5025                    37515       Delta County  1/1/2014
# 5061                    40892    Franklin County  1/1/2014
# 5247                    51340      Orange County  1/1/2015
# 5000                    70322       Comal County  1/1/2015
# 4992                    33014     Coleman County  1/1/2015
# 4953                    39235    Brewster County  1/1/2014
# 5232                    36366      Morris County  1/1/2015
# 5016                    42378      Dallam County  1/1/2015
# 5131                    42821        Hunt County  1/1/2014
# 5103                    44958    Harrison County  1/1/2014
# 5248                    40817  Palo Pinto County  1/1/2014
# 5193                    41555     Lubbock County  1/1/2014
# 5227                    65874  Montgomery County  1/1/2014
# 5110                    59260        Hays County  1/1/2015
# 5119                    46010     Hockley County  1/1/2014
# 5042                    40092     El Paso County  1/1/2014
# 4984                    33919   Childress County  1/1/2015
# 5318                    56906     Tarrant County  1/1/2015
# 5176                    48746    Lampasas County  1/1/2015
# 5325                    43393   Tom Green County  1/1/2014
# 5015                    40312      Dallam County  1/1/2014
# 5182                    43617        Leon County  1/1/2015
# 4964                    46021    Caldwell County  1/1/2015
# 4976                    37546        Cass County  1/1/2015
# 5087                    62141   Guadalupe County  1/1/2014
# 5230                    46991       Moore County  1/1/2015
# 4979                    73031    Chambers County  1/1/2014
# 4944                    54914      Blanco County  1/1/2015
# 5298                    49340      Scurry County  1/1/2014
# 5129                    30043    Hudspeth County  1/1/2014
# 5052                    46907     Fayette County  1/1/2014
# 5314                    59098      Sutton County  1/1/2015
# 5327                    57293      Travis County  1/1/2014
# 4954                    39106    Brewster County  1/1/2015
# 4927                    51448      Austin County  1/1/2014
# 5019                    36312      Dawson County  1/1/2014
# 5022                    45937      DeWitt County  1/1/2015
# 5200                    36090      Marion County  1/1/2015
# 4939                    48391        Bell County  1/1/2014
# 5010                    58901       Crane County  1/1/2015
# 5219                    38715       Milam County  1/1/2014
# 5250                    50916      Panola County  1/1/2014

# %% [markdown]
# Within the TX_subset we created earlier, make a smaller data subset with the specific Median household income data by county, which will be your final data.

# %% [markdown]
# Create a name for this final data, in which I chose "Medianincometx". To make "Medianincometx" an actual subset you need to use the code
# `Medianincometx= TX_subset.loc[:,["Median household income","County","Year"]].sample(n=40)`

# %% [markdown]
# Then on a new line of code type `Medianincometx` which is your finished sorted data and that will present the data you have just sorted

# %%
Medianincometx= TX_subset.loc[:,["Median household income","County","Year"]].sample(n=50)

Medianincometx
# Out:
#       Median household income            County      Year
# 4929                    38504     Bailey County  1/1/2014
# 5303                    36565     Shelby County  1/1/2015
# 4914                    41530   Anderson County  1/1/2014
# 5197                    36579    Madison County  1/1/2014
# 5165                    39237    Kleberg County  1/1/2014
# 4923                    56805     Archer County  1/1/2015
# 5246                    49238     Orange County  1/1/2014
# 5092                    30380       Hall County  1/1/2015
# 5357                    47012    Wheeler County  1/1/2014
# 5245                    52431     Oldham County  1/1/2015
# 5107                    31505    Haskell County  1/1/2014
# 5376                    57995     Yoakum County  1/1/2015
# 4927                    51448     Austin County  1/1/2014
# 5150                    55960    Johnson County  1/1/2015
# 5373                    45466       Wood County  1/1/2014
# 5013                    36492     Crosby County  1/1/2014
# 5224                    47677   Mitchell County  1/1/2015
# 4973                    53302     Carson County  1/1/2014
# 5072                    47134      Garza County  1/1/2015
# 5218                    71151    Midland County  1/1/2015
# 5285                    44349       Rusk County  1/1/2015
# 5030                    33342     Dimmit County  1/1/2014
# 5214                    53714     Medina County  1/1/2015
# 5082                    44596    Grayson County  1/1/2015
# 5358                    51922    Wheeler County  1/1/2015
# 5179                    49906        Lee County  1/1/2014
# 4941                    49651      Bexar County  1/1/2014
# 5271                    34556       Real County  1/1/2015
# 5340                    38645  Val Verde County  1/1/2015
# 4935                    33164     Baylor County  1/1/2014
# 5185                    36496  Limestone County  1/1/2014
# 4924                    52122  Armstrong County  1/1/2015
# 5232                    36366     Morris County  1/1/2015
# 5122                    59053       Hood County  1/1/2015
# 5027                    71338     Denton County  1/1/2014
# 5094                    39448   Hamilton County  1/1/2015
# 5154                    43413     Karnes County  1/1/2015
# 5205                    40860  Matagorda County  1/1/2014
# 5313                    60695     Sutton County  1/1/2014
# 5311                    40805   Stephens County  1/1/2014
# 5283                    36769    Runnels County  1/1/2015
# 5022                    45937     DeWitt County  1/1/2015
# 4997                    40702   Colorado County  1/1/2014
# 5201                    47358     Martin County  1/1/2014
# 5308                    56282  Somervell County  1/1/2015
# 4928                    52042     Austin County  1/1/2015
# 5266                    56716    Randall County  1/1/2014
# 5009                    55599      Crane County  1/1/2014
# 5282                    35593    Runnels County  1/1/2014
# 5042                    40092    El Paso County  1/1/2014

# %% [markdown]
# Finally to export your final data use the line of code `Medianincometx.to_csv('Medianincometx.csv')`

# %%
Medianincometx.to_csv('Medianincometx.csv')

# %% [markdown]
# With that code enetered, you should have a new file called Medianincometx in your files within your notebook
